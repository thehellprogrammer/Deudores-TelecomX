# %% [markdown]
# <a href="https://colab.research.google.com/github/thehellprogrammer/Deudores-TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
datos_TelecomX = pd.read_json('TelecomX_Data.json')

# %%
original = datos_TelecomX
original.info()
columna_extraida = original['Churn']
print(columna_extraida)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %% [markdown]
# #🔧 Transformación

# %%
customer = pd.json_normalize(datos_TelecomX['customer'])

# %%
phone = pd.json_normalize(datos_TelecomX['phone'])

# %%
internet = pd.json_normalize(datos_TelecomX['internet'])

# %%
account = pd.json_normalize(datos_TelecomX['account'])

# %%
Unido = pd.concat([columna_extraida ,customer, phone, internet, account], axis=1)

Deudores =Unido[Unido['Churn'] == 'Yes']
NoDeudores =Unido[Unido['Churn'] == 'No']
#Unido_female = Unido[Unido['gender'] == 'Female']
#Unido_Male = Unido[Unido['gender'] == 'Male']
Deudores.info()
NoDeudores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1869 entries, 2 to 7263
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Churn             1869 non-null   object
#  1   gender            1869 non-null   object
#  2   SeniorCitizen     1869 non-null   int64
#  3   Partner           1869 non-null   object
#  4   Dependents        1869 non-null   object
#  5   tenure            1869 non-null   int64
#  6   PhoneService      1869 non-null   object
#  7   MultipleLines     1869 non-null   object
#  8   InternetService   1869 non-null   object
#  9   OnlineSecurity    1869 non-null   object
#  10  OnlineBackup      1869 non-null   object
#  11  DeviceProtection  1869 non-null   object
#  12  TechSupport       1869 non-null   object
#  13  StreamingTV       1869 non-null   object
#  14  StreamingMovies   1869 non-null   object
#  15  Contract          1869 non-null   object
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
px.pie(Deudores, names='gender', title='Distribución de Género')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(Deudores, names='PaymentMethod', title='metodo de pago')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(Deudores, x="Contract",text_auto=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(NoDeudores, names='PaymentMethod', title='metodo de pago')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #📄Informe final

# %%
churn_by_gender = Deudores['gender'].value_counts(normalize=True) * 100
print("Porcentaje de evasión por género:")
print(churn_by_gender)

churn_by_contract = Deudores['Contract'].value_counts(normalize=True) * 100
print("\nPorcentaje de evasión por tipo de contrato:")
print(churn_by_contract)
# Out:
# Porcentaje de evasión por género:
# gender
# Female    50.24077
# Male      49.75923
# Name: proportion, dtype: float64
#
# Porcentaje de evasión por tipo de contrato:
# Contract
# Month-to-month    88.550027
# One year           8.881755
# Two year           2.568218
# Name: proportion, dtype: float64
